# %% [markdown]
# <a href="https://colab.research.google.com/github/tarannump096-cpu/Project/blob/main/DEEP_LEARNING2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import numpy as np
def sigmoid(x):
    return 1 / (1 + np.exp(-x))
def building_NN_Logistic_regression(inputs,weights,bias):
    result=0
    result=np.sum(inputs*weights)+bias
    predict=sigmoid(result)
    return predict

# %%
inputs=np.random.randn(0,1,10)
weights=np.random.randn(0,1,10)
bias=0.5
result=building_NN_Logistic_regression(inputs,weights,bias)

# %%
result
# Out:
# np.float64(0.6224593312018546)

# %%
import numpy as np
def sigmoid(x):
    return 1 / (1 + np.exp(-x))
def building_NN_Logistic_regression(inputs,weights,bias):
    result=0
    result=np.sum(inputs*weights)+bias
    predict=sigmoid(result)
    return predict

# %%
inputs=np.random.randn(0,1,10)
weights=np.random.randn(0,1,10)
bias=0.5
result=building_NN_Logistic_regression(inputs,weights,bias)

# %%
inputs=np.random.randn(1,1,10)
weights=np.random.randn(2,1,10)
bias=0.5
result=building_NN_Logistic_regression(inputs,weights,bias)
